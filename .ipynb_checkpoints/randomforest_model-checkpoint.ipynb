# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\kim\anaconda3\envs\pythondata\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\kim\anaconda3\envs\pythondata\lib\site-packages (from sklearn) (0.23.2)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\kim\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\kim\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.5.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\kim\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\kim\anaconda3\envs\pythondata\lib\site-packages (from scikit-learn->sklearn) (1.17.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\kim\anaconda3\envs\pythondata\lib\site-packages (0.16.0)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head(100)
# Out:
#    koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0        CONFIRMED              0              0              0
# 1   FALSE POSITIVE              0              1              0
# 2   FALSE POSITIVE              0              1              0
# 3        CONFIRMED              0              0              0
# 4        CONFIRMED              0              0              0
# ..             ...            ...            ...            ...
# 95       CONFIRMED              0              0              0
# 96       CONFIRMED              0              0              0
# 97       CONFIRMED              0              0              0
# 98       CONFIRMED              0              0              0
# 99       CONFIRMED              0              0              0
#
#     koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0               0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1               0   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2               0    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3               0    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4               0    4.134435     1.050000e-05    -1.050000e-05   172.979370
# ..            ...         ...              ...              ...          ...
# 95              0    8.103633     2.030000e-05    -2.030000e-05   176.948600
# 96              0    4.715108     1.940000e-05    -1.940000e-05   134.961780
# 97              0    6.365840     8.060000e-06    -8.060000e-06   171.135750
# 98              0    3.040330     3.370000e-07    -3.370000e-07   169.949011
# 99              0   31.330461     3.980000e-05    -3.980000e-05   153.430310
#
#     koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0           0.003520  ...             -81      4.467           0.064
# 1           0.000581  ...            -176      4.544           0.044
# 2           0.000115  ...            -174      4.564           0.053
# 3           0.001130  ...            -211      4.438           0.070
# 4           0.001900  ...            -232      4.486           0.054
# ..               ...  ...             ...        ...             ...
# 95          0.002050  ...            -146      4.574           0.054
# 96          0.003240  ...            -146      4.574           0.054
# 97          0.001000  ...            -155      4.554           0.042
# 98          0.000089  ...            -151      4.519           0.084
# 99          0.001030  ...            -105      4.581           0.010
#
#     koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0           -0.096     0.927          0.105         -0.061  291.93423
# 1           -0.176     0.868          0.233         -0.078  297.00482
# 2           -0.168     0.791          0.201         -0.067  285.53461
# 3           -0.210     1.046          0.334         -0.133  288.75488
# 4           -0.229     0.972          0.315         -0.105  296.28613
# ..             ...       ...            ...            ...        ...
# 95          -0.041     0.732          0.062         -0.068  283.22141
# 96          -0.041     0.732          0.062         -0.068  283.22141
# 97          -0.168     0.849          0.212         -0.071  291.14951
# 98          -0.063     0.791          0.071         -0.087  299.31610
# 99          -0.085     0.817          0.080         -0.029  292.23676
#
#           dec  koi_kepmag
# 0   48.141651      15.347
# 1   48.134129      15.436
# 2   48.285210      15.597
# 3   48.226200      15.509
# 4   48.224670      15.714
# ..        ...         ...
# 95  40.421829      15.289
# 96  40.421829      15.289
# 97  40.420521      15.090
# 98  40.822380      15.028
# 99  41.085880      15.855
#
# [100 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6991 entries, 0 to 6990
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   koi_disposition    6991 non-null   object
#  1   koi_fpflag_nt      6991 non-null   int64
#  2   koi_fpflag_ss      6991 non-null   int64
#  3   koi_fpflag_co      6991 non-null   int64
#  4   koi_fpflag_ec      6991 non-null   int64
#  5   koi_period         6991 non-null   float64
#  6   koi_period_err1    6991 non-null   float64
#  7   koi_period_err2    6991 non-null   float64
#  8   koi_time0bk        6991 non-null   float64
#  9   koi_time0bk_err1   6991 non-null   float64
#  10  koi_time0bk_err2   6991 non-null   float64
#  11  koi_impact         6991 non-null   float64
#  12  koi_impact_err1    6991 non-null   float64
#  13  koi_impact_err2    6991 non-null   float64
#  14  koi_duration       6991 non-null   float64
#  15  koi_duration_err1  6991 non-null   float64
#  16  koi_duration_err2  6991 non-null   float64
#  17  koi_depth          6991 non-null   float64
#  18  koi_depth_err1     6991 non-null   float64
#  19  koi_depth_err2     6991 non-null   float64
#  20  koi_prad           6991 non-null   float64
#  21  koi_prad_err1      6991 non-null   float64
#  22  koi_prad_err2      6991 non-null   float64
#  23  koi_teq            6991 non-null   int64
#  24  koi_insol          6991 non-null   float64
#  25  koi_insol_err1     6991 non-null   float64
#  26  koi_insol_err2     6991 non-null   float64
#  27  koi_model_snr      6991 non-null   float64
#  28  koi_tce_plnt_num   6991 non-null   int64
#  29  koi_steff          6991 non-null   int64
#  30  koi_steff_err1     6991 non-null   int64
#  31  koi_steff_err2     6991 non-null   int64
#  32  koi_slogg          6991 non-null   float64
#  33  koi_slogg_err1     6991 non-null   float64
#  34  koi_slogg_err2     6991 non-null   float64
#  35  koi_srad           6991 non-null   float64
#  36  koi_srad_err1      6991 non-null   float64
#  37  koi_srad_err2      6991 non-null   float64
#  38  ra                 6991 non-null   float64
#  39  dec                6991 non-null   float64
#  40  koi_kepmag         6991 non-null   float64
# dtypes: float64(31), int64(9), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df.drop(["koi_disposition",'koi_tce_plnt_num', 'koi_srad_err2', 'koi_slogg_err1',
                             'koi_steff', 'koi_srad', 'koi_slogg'], axis=1)

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
y = df["koi_disposition"]
print(selected_features.shape, y.shape)
# Out:
# (6991, 34) (6991,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
X_train, X_test, y_train, y_test = train_test_split(selected_features, y, random_state=1)
X_train.head()
# Out:
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3563              0              0              0              0   10.548413
# 4099              0              0              0              0   24.754385
# 5460              0              0              0              0    1.057336
# 1091              0              0              0              0  201.118319
# 5999              0              0              0              0   91.649983
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3563     5.470000e-05    -5.470000e-05   139.064020          0.004110
# 4099     1.365000e-04    -1.365000e-04   140.207320          0.004460
# 5460     1.230000e-07    -1.230000e-07   131.792007          0.000096
# 1091     1.461000e-03    -1.461000e-03   187.569860          0.005290
# 5999     3.181000e-03    -3.181000e-03   175.715600          0.028600
#
#       koi_time0bk_err2  ...  koi_insol_err1  koi_insol_err2  koi_model_snr  \
# 3563         -0.004110  ...           72.78          -37.23           11.7
# 4099         -0.004460  ...            3.92           -3.75           18.0
# 5460         -0.000096  ...          184.18         -164.28          476.0
# 1091         -0.005290  ...            0.77           -0.44           34.7
# 5999         -0.028600  ...           41.53          -12.19            8.7
#
#       koi_steff_err1  koi_steff_err2  koi_slogg_err2  koi_srad_err1  \
# 3563             120            -133          -0.123          0.181
# 4099             144            -144          -0.052          0.056
# 5460             126            -140          -0.027          0.054
# 1091             101            -112          -0.108          0.135
# 5999             164            -233          -0.164          0.905
#
#              ra        dec  koi_kepmag
# 3563  298.09543  44.737061      13.204
# 4099  295.73535  42.576248      15.514
# 5460  292.18417  49.310040      15.414
# 1091  283.11377  48.131390      13.328
# 5999  294.93198  39.812420      12.964
#
# [5 rows x 34 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

label_encoder = LabelEncoder()
label_encoder.fit(y_train)
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=400)
model.fit(X_train_scaled, y_train)
predictions = model.predict(X_test_scaled)
print(predictions)

print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# [1 2 2 ... 2 2 0]
# Training Data Score: 1.0
# Testing Data Score: 0.9124713958810069

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions, 
                            target_names = ["Confirmed", "False Positive", "Candidate"]))
# Out:
#                 precision    recall  f1-score   support
#
#      Confirmed       0.85      0.76      0.81       404
# False Positive       0.82      0.87      0.84       435
#      Candidate       0.98      1.00      0.99       909
#
#       accuracy                           0.91      1748
#      macro avg       0.88      0.88      0.88      1748
#   weighted avg       0.91      0.91      0.91      1748

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion': ['gini', 'entropy'],
             'n_estimators':[100,500,1000]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] criterion=gini, n_estimators=100 ................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .... criterion=gini, n_estimators=100, score=0.881, total=   1.7s
# [CV] criterion=gini, n_estimators=100 ................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [CV] .... criterion=gini, n_estimators=100, score=0.900, total=   1.6s
# [CV] criterion=gini, n_estimators=100 ................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.2s remaining:    0.0s
# [CV] .... criterion=gini, n_estimators=100, score=0.891, total=   1.6s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.891, total=   1.5s
# [CV] criterion=gini, n_estimators=100 ................................
# [CV] .... criterion=gini, n_estimators=100, score=0.874, total=   1.5s
# [CV] criterion=gini, n_estimators=500 ................................
# [CV] .... criterion=gini, n_estimators=500, score=0.885, total=   7.2s
# [CV] criterion=gini, n_estimators=500 ................................
# [CV] .... criterion=gini, n_estimators=500, score=0.904, total=   7.5s
# [CV] criterion=gini, n_estimators=500 ................................
# [CV] .... criterion=gini, n_estimators=500, score=0.898, total=   7.5s
# [CV] criterion=gini, n_estimators=500 ................................
# [CV] .... criterion=gini, n_estimators=500, score=0.892, total=   8.0s
# [CV] criterion=gini, n_estimators=500 ................................
# [CV] .... criterion=gini, n_estimators=500, score=0.874, total=   7.7s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.884, total=  15.3s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.900, total=  14.9s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.898, total=  14.8s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.888, total=  14.9s
# [CV] criterion=gini, n_estimators=1000 ...............................
# [CV] ... criterion=gini, n_estimators=1000, score=0.874, total=  14.7s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.884, total=   2.1s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.897, total=   2.1s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.888, total=   2.1s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.886, total=   2.1s
# [CV] criterion=entropy, n_estimators=100 .............................
# [CV] . criterion=entropy, n_estimators=100, score=0.874, total=   2.1s
# [CV] criterion=entropy, n_estimators=500 .............................
# [CV] . criterion=entropy, n_estimators=500, score=0.887, total=  11.2s
# [CV] criterion=entropy, n_estimators=500 .............................
# [CV] . criterion=entropy, n_estimators=500, score=0.899, total=  10.4s
# [CV] criterion=entropy, n_estimators=500 .............................
# [CV] . criterion=entropy, n_estimators=500, score=0.901, total=  10.4s
# [CV] criterion=entropy, n_estimators=500 .............................
# [CV] . criterion=entropy, n_estimators=500, score=0.892, total=  10.6s
# [CV] criterion=entropy, n_estimators=500 .............................
# [CV] . criterion=entropy, n_estimators=500, score=0.877, total=  10.4s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.885, total=  29.4s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.903, total=  24.6s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.903, total=  23.9s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.894, total=  24.1s
# [CV] criterion=entropy, n_estimators=1000 ............................
# [CV]  criterion=entropy, n_estimators=1000, score=0.875, total=  23.9s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  5.2min finished
# GridSearchCV(estimator=RandomForestClassifier(n_estimators=400),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': [100, 500, 1000]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'criterion': 'entropy', 'n_estimators': 1000}
# 0.8918530188692977

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'randomforest_model.sav'
joblib.dump(model, filename)
# Out:
# ['randomforest_model.sav']
